# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import socket
import os

# %%
# Paths for running on Mac

if (socket.gethostname() == 'research'):
    print("On host: research")
    imagesDir = '/media/sf_hellmersjl/bitbucket/books/book01'
    rateDir = '/media/sf_hellmersjl/bitbucket/pycnocalc/researchdata'
else:
    print("On host: " + socket.gethostname())
    imagesDir = '/Users/hellmersjl/bitbucket/books/book01'
    rateDir = '/Users/hellmersjl/bitbucket/pycnocalc/researchdata'

# Paths for running on 
#help(os)
#print(os.name)
# Out:
# On host: Iscandar.local

# %%
dfm3y = pd.read_csv(rateDir + "/pycno_rates_C-C_TO_ND_M3Y_2.csv",index_col=False,skipinitialspace=True)
dfrmf = pd.read_csv(rateDir + "/pycno_rates_C-C_TO_ND_RMF_2.csv",index_col=False,skipinitialspace=True)

# %%
dfm3y_bcc_relax = dfm3y

dfrmf_bcc_relax = dfrmf

#dfm3y_bcc_relax = dfm3y.query('nninteraction == "M3Y-bcc-relax"')

#dfrmf_bcc_relax = dfrmf.query('nninteraction == "RMF-bcc-relax"')

dfm3y_bcc_relax   = dfm3y_bcc_relax.rename(columns ={"pycno_rate": "M3Y-bcc-relaxed"})

dfrmf_bcc_relax   = dfrmf_bcc_relax.rename(columns ={"pycno_rate": "RMF-bcc-relaxed"})

# %%
thisXlim = [1.0e10,3.9e10]
ax = dfm3y_bcc_relax.plot(       x='density', y='M3Y-bcc-relaxed'      ,style='k--',xlim=thisXlim)
dfrmf_bcc_relax.plot     (ax=ax, x='density', y='RMF-bcc-relaxed'      ,style='r-' ,xlim=thisXlim)
ax.set_xlabel("Density (g/$\\rm cm^3$)")
ax.set_ylabel("Rxn Rate (count/$\\rm cm^3$/sec)")
#ax.set_title("bcc relaxed - Rxn Rate vs. Density")
plt.savefig(imagesDir + '/' + 'Schramm_bcc_relaxed_Rates.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
thisXlim = [10.0e10,1.0e12]
ax = dfm3y_bcc_relax.plot(       x='density', y='M3Y-bcc-relaxed'      ,style='k--',xlim=thisXlim)
dfrmf_bcc_relax.plot     (ax=ax, x='density', y='RMF-bcc-relaxed'      ,style='r-' ,xlim=thisXlim)
ax.set_xlabel("Density (g/$\\rm cm^3$)")
ax.set_ylabel("Rxn Rate (count/$\\rm cm^3$/sec)")
#ax.set_title("bcc relaxed - Rxn Rate vs. Density")
plt.savefig(imagesDir + '/' + 'Schramm_bcc_relaxed_Rates.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
thisXlim = [0.8e11,1.0e11]
ax = dfm3y_fcc_relax.plot(       x='density', y='M3Y-fcc-relaxed'      ,xlim=thisXlim)
dfsaopaulo_fcc_relax.plot(ax=ax, x='density', y='Sao Paulo-fcc-relaxed',xlim=thisXlim)
dfrmf_fcc_relax.plot     (ax=ax, x='density', y='RMF-fcc-relaxed'      ,xlim=thisXlim)
ax.set_xlabel("Density (g/$\\rm cm^3$)")
ax.set_ylabel("Rxn Rate (count/$\\rm cm^3$/sec)")
ax.set_title("fcc relaxed - Rxn Rate vs. Density")

# %%
dfSFactor = pd.read_csv("../researchdata/graphSFactor.csv",index_col=False,skipinitialspace=True)

# %%
ax = dfSFactor.plot(kind='line',x='Density',y=['M3Y','RMF'],style=['k--','g-.','r-'])
ax.set_xlabel("Density (g/$\\rm cm^3$)")
ax.set_ylabel("S Factor (MeV-barns)")
plt.savefig(imagesDir + '/' + 'SFactor.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
dftempadjustrho10 = pd.read_csv("../researchdata/temp_adjust_rho10.csv",index_col=False,skipinitialspace=True)

# %%
ax = dftempadjustrho10.plot(kind='line',x='temp',y=['adjust'],style=['k--'])
ax.set_xlabel("Temperature (K)")
ax.set_ylabel("Pycno Rxn Rate Multiplier")
#ax.set_title("Rate Adjust vs. Temp, rho=10^10")
ax.legend(["Multiplier"]);
plt.savefig(imagesDir + '/' + 'RateTempAdjust10.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
dftempadjustrho10
# Out:
#            temp        adjust
# 0    26000000.0  1.389233e+00
# 1    39480000.0  3.311263e+03
# 2    52960000.0  4.444175e+07
# 3    66440000.0  4.334157e+10
# 4    79920000.0  3.424390e+12
# 5    93400000.0  4.884135e+13
# 6   106880000.0  2.400828e+14
# 7   120360000.0  6.169287e+14
# 8   133840000.0  1.067533e+15
# 9   147320000.0  1.448753e+15
# 10  160800000.0  1.691260e+15
# 11  174280000.0  1.797584e+15
# 12  187760000.0  1.802189e+15
# 13  201240000.0  1.742817e+15
# 14  214720000.0  1.649092e+15
# 15  228200000.0  1.540898e+15
# 16  241680000.0  1.430291e+15
# 17  255160000.0  1.323947e+15
# 18  268640000.0  1.225154e+15
# 19  282120000.0  1.135196e+15
# 20  295600000.0  1.054231e+15
# 21  309080000.0  9.818314e+14
# 22  322560000.0  9.172957e+14
# 23  336040000.0  8.598282e+14
# 24  349520000.0  8.086338e+14
# 25  363000000.0  7.629656e+14
# 26  376480000.0  7.221464e+14
# 27  389960000.0  6.855746e+14
# 28  403440000.0  6.527223e+14
# 29  416920000.0  6.231300e+14
# 30  430400000.0  5.963992e+14
# 31  443880000.0  5.721851e+14
# 32  457360000.0  5.501895e+14
# 33  470840000.0  5.301545e+14
# 34  484320000.0  5.118568e+14
# 35  497800000.0  4.951024e+14
# 36  511280000.0  4.797230e+14
# 37  524760000.0  4.655718e+14
# 38  538240000.0  4.525207e+14
# 39  551720000.0  4.404574e+14
# 40  565200000.0  4.292835e+14
# 41  578680000.0  4.189122e+14
# 42  592160000.0  4.092672e+14
# 43  605640000.0  4.002807e+14
# 44  619120000.0  3.918928e+14
# 45  632600000.0  3.840502e+14
# 46  646080000.0  3.767054e+14
# 47  659560000.0  3.698159e+14
# 48  673040000.0  3.633437e+14
# 49  686520000.0  3.572548e+14
# 50  700000000.0  3.515184e+14
