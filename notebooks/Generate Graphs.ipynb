# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import socket

# %%
# Paths for running on Mac

if (socket.gethostname() == 'research'):
    print("On host: research")
    imagesDir = '/media/sf_hellmersjl/bitbucket/hellmers_ms/thesis_doc/Figures'
    rateDir = '/media/sf_hellmersjl/bitbucket/pycnocalc/researchdata'
else:
    print("On host: " + socket.gethostname())
    imagesDir = '/Users/hellmersjl/bitbucket/hellmers_ms/thesis_doc/Figures'
    rateDir = '/Users/hellmersjl/bitbucket/pycnocalc/researchdata'

# Paths for running on 
#help(os)
#print(os.name)

# %%
dfsaopaulo = pd.read_csv(rateDir + "/pycno_rates_C-C_WD_SaoPaulo.csv",index_col=False,skipinitialspace=True)
dfm3y = pd.read_csv(rateDir + "/pycno_rates_C-C_WD_M3Y.csv",index_col=False,skipinitialspace=True)
dfrmf = pd.read_csv(rateDir + "/pycno_rates_C-C_WD_RMF.csv",index_col=False,skipinitialspace=True)
dfg05low = pd.read_csv(rateDir + "/pycno_rates_C-C_WD_G05Low.csv",index_col=False,skipinitialspace=True)
dfg05high = pd.read_csv(rateDir + "/pycno_rates_C-C_WD_G05High.csv",index_col=False,skipinitialspace=True)
dfsaopaulo['nninteraction'] = dfsaopaulo['nninteraction'].str.strip()
dfm3y['nninteraction'] = dfm3y['nninteraction'].str.strip()
dfrmf['nninteraction'] = dfrmf['nninteraction'].str.strip()
dfg05low['nninteraction'] = dfg05low['nninteraction'].str.strip()
dfg05high['nninteraction'] = dfg05high['nninteraction'].str.strip()

# %%
dfsaopaulo_spvh = dfsaopaulo.query('nninteraction == "SAOPAULO-SPVH"')
dfsaopaulo_bcc_static = dfsaopaulo.query('nninteraction == "SAOPAULO-bcc-static"')
dfsaopaulo_bcc_ws = dfsaopaulo.query('nninteraction == "SAOPAULO-bcc-ws"')
dfsaopaulo_bcc_relax = dfsaopaulo.query('nninteraction == "SAOPAULO-bcc-relax"')
dfsaopaulo_fcc_static = dfsaopaulo.query('nninteraction == "SAOPAULO-fcc-static"')
dfsaopaulo_fcc_ws = dfsaopaulo.query('nninteraction == "SAOPAULO-fcc-ws"')
dfsaopaulo_fcc_relax = dfsaopaulo.query('nninteraction == "SAOPAULO-fcc-relax"')

dfm3y_spvh = dfm3y.query('nninteraction == "M3Y-SPVH"')
dfm3y_bcc_static = dfm3y.query('nninteraction == "M3Y-bcc-static"')
dfm3y_bcc_ws = dfm3y.query('nninteraction == "M3Y-bcc-ws"')
dfm3y_bcc_relax = dfm3y.query('nninteraction == "M3Y-bcc-relax"')
dfm3y_fcc_static = dfm3y.query('nninteraction == "M3Y-fcc-static"')
dfm3y_fcc_ws = dfm3y.query('nninteraction == "M3Y-fcc-ws"')
dfm3y_fcc_relax = dfm3y.query('nninteraction == "M3Y-fcc-relax"')

dfrmf_spvh = dfrmf.query('nninteraction == "RMF-SPVH"')
dfrmf_bcc_static = dfrmf.query('nninteraction == "RMF-bcc-static"')
dfrmf_bcc_ws = dfrmf.query('nninteraction == "RMF-bcc-ws"')
dfrmf_bcc_relax = dfrmf.query('nninteraction == "RMF-bcc-relax"')
dfrmf_fcc_static = dfrmf.query('nninteraction == "RMF-fcc-static"')
dfrmf_fcc_ws = dfrmf.query('nninteraction == "RMF-fcc-ws"')
dfrmf_fcc_relax = dfrmf.query('nninteraction == "RMF-fcc-relax"')


dfsaopaulo_spvh       = dfsaopaulo_spvh.rename(columns      ={"pycno_rate": "Sao Paulo-SPVH"})
dfsaopaulo_bcc_static = dfsaopaulo_bcc_static.rename(columns={"pycno_rate": "Sao Paulo-bcc-static"})
dfsaopaulo_bcc_ws     = dfsaopaulo_bcc_ws.rename(columns    ={"pycno_rate": "Sao Paulo-bcc-ws"})
dfsaopaulo_bcc_relax  = dfsaopaulo_bcc_relax.rename(columns ={"pycno_rate": "Sao Paulo-bcc-relaxed"})
dfsaopaulo_fcc_static = dfsaopaulo_fcc_static.rename(columns={"pycno_rate": "Sao Paulo-fcc-static"})
dfsaopaulo_fcc_ws     = dfsaopaulo_fcc_ws.rename(columns    ={"pycno_rate": "Sao Paulo-fcc-ws"})
dfsaopaulo_fcc_relax  = dfsaopaulo_fcc_relax.rename(columns ={"pycno_rate": "Sao Paulo-fcc-relaxed"})

dfm3y_spvh        = dfm3y_spvh.rename(columns      ={"pycno_rate": "M3Y-SPVH"})
dfm3y_bcc_static  = dfm3y_bcc_static.rename(columns={"pycno_rate": "M3Y-bcc-static"})
dfm3y_bcc_ws      = dfm3y_bcc_ws.rename(columns    ={"pycno_rate": "M3Y-bcc-ws"})
dfm3y_bcc_relax   = dfm3y_bcc_relax.rename(columns ={"pycno_rate": "M3Y-bcc-relaxed"})
dfm3y_fcc_static  = dfm3y_fcc_static.rename(columns={"pycno_rate": "M3Y-fcc-static"})
dfm3y_fcc_ws      = dfm3y_fcc_ws.rename(columns    ={"pycno_rate": "M3Y-fcc-ws"})
dfm3y_fcc_relax   = dfm3y_fcc_relax.rename(columns ={"pycno_rate": "M3Y-fcc-relaxed"})

dfrmf_spvh        = dfrmf_spvh.rename(columns      ={"pycno_rate": "RMF-SPVH"})
dfrmf_bcc_static  = dfrmf_bcc_static.rename(columns={"pycno_rate": "RMF-bcc-static"})
dfrmf_bcc_ws      = dfrmf_bcc_ws.rename(columns    ={"pycno_rate": "RMF-bcc-ws"})
dfrmf_bcc_relax   = dfrmf_bcc_relax.rename(columns ={"pycno_rate": "RMF-bcc-relaxed"})
dfrmf_fcc_static  = dfrmf_fcc_static.rename(columns={"pycno_rate": "RMF-fcc-static"})
dfrmf_fcc_ws      = dfrmf_fcc_ws.rename(columns    ={"pycno_rate": "RMF-fcc-ws"})
dfrmf_fcc_relax   = dfrmf_fcc_relax.rename(columns ={"pycno_rate": "RMF-fcc-relaxed"})

dfg05low    = dfg05low.rename(columns  ={"pycno_rate": "G05-Zero Temp"})
dfg05high   = dfg05high.rename(columns ={"pycno_rate": "G05-10^10 Temp"})

# %%
thisXlim = [0.8e11,1.0e11]
ax = dfg05low.plot(       x='density', y='G05-Zero Temp'    ,style='k--',xlim=thisXlim)
dfg05high.plot    (ax=ax, x='density', y='G05-10^10 Temp'   ,style='g-.',xlim=thisXlim)

ax.set_xlabel("Density (g/$\\rm cm^3$)")
ax.set_ylabel("Rxn Rate (count/$\\rm cm^3$/sec)")
#ax.set_title("G05 - Rxn Rate vs. Density")
plt.savefig(imagesDir + '/' + 'G05_Rates.eps')

# %%
thisXlim = [0.8e11,1.0e11]
ax = dfg05low.plot(       x='density', y='G05-Zero Temp'    ,style='k--',xlim=thisXlim)
dfg05high.plot    (ax=ax, x='density', y='G05-10^10 Temp'   ,style='g-.',xlim=thisXlim)

ax.set_xlabel("Density (g/$\\rm cm^3$)")
ax.set_ylabel("Rxn Rate (count/$\\rm cm^3$/sec)")
ax.set_title("G05 - Rxn Rate vs. Density")
plt.savefig(imagesDir + '/' + 'G05_Rates-with-title.eps')

# %%
thisXlim = [0.8e11,1.0e11]
ax = dfm3y_spvh.plot(       x='density', y='M3Y-SPVH'      ,style='k--',xlim=thisXlim)
dfsaopaulo_spvh.plot(ax=ax, x='density', y='Sao Paulo-SPVH',style='g-.',xlim=thisXlim)
dfrmf_spvh.plot     (ax=ax, x='density', y='RMF-SPVH'      ,style='r-' ,xlim=thisXlim)

ax.set_xlabel("Density (g/$\\rm cm^3$)")
ax.set_ylabel("Rxn Rate (count/$\\rm cm^3$/sec)")
#ax.set_title("SPVH - Rxn Rate vs. Density")
plt.savefig(imagesDir + '/' + 'SPVH_NN_Rates.eps')

# %%
thisXlim = [0.8e11,1.0e11]
ax = dfm3y_bcc_static.plot(       x='density', y='M3Y-bcc-static'      ,xlim=thisXlim)
dfsaopaulo_bcc_static.plot(ax=ax, x='density', y='Sao Paulo-bcc-static',xlim=thisXlim)
dfrmf_bcc_static.plot     (ax=ax, x='density', y='RMF-bcc-static'      ,xlim=thisXlim)
ax.set_xlabel("Density (g/$\\rm cm^3$)")
ax.set_ylabel("Rxn Rate (count/$\\rm cm^3$/sec)")
ax.set_title("bcc static - Rxn Rate vs. Density")

# %%
thisXlim = [0.8e11,1.0e11]
ax = dfm3y_bcc_ws.plot(       x='density', y='M3Y-bcc-ws'      ,xlim=thisXlim)
dfsaopaulo_bcc_ws.plot(ax=ax, x='density', y='Sao Paulo-bcc-ws',xlim=thisXlim)
dfrmf_bcc_ws.plot     (ax=ax, x='density', y='RMF-bcc-ws'      ,xlim=thisXlim)
ax.set_xlabel("Density (g/$\\rm cm^3$)")
ax.set_ylabel("Rxn Rate (count/$\\rm cm^3$/sec)")
ax.set_title("bcc ws - Rxn Rate vs. Density")

# %%
thisXlim = [0.8e11,1.0e11]
ax = dfm3y_bcc_relax.plot(       x='density', y='M3Y-bcc-relaxed'      ,style='k--',xlim=thisXlim)
dfsaopaulo_bcc_relax.plot(ax=ax, x='density', y='Sao Paulo-bcc-relaxed',style='g-.',xlim=thisXlim)
dfrmf_bcc_relax.plot     (ax=ax, x='density', y='RMF-bcc-relaxed'      ,style='r-' ,xlim=thisXlim)
ax.set_xlabel("Density (g/$\\rm cm^3$)")
ax.set_ylabel("Rxn Rate (count/$\\rm cm^3$/sec)")
#ax.set_title("bcc relaxed - Rxn Rate vs. Density")
plt.savefig(imagesDir + '/' + 'Schramm_bcc_relaxed_Rates.eps')

# %%
thisXlim = [0.8e11,1.0e11]
ax = dfm3y_bcc_relax.plot(       x='density', y='M3Y-bcc-relaxed'      ,style='k--',xlim=thisXlim)
dfsaopaulo_bcc_relax.plot(ax=ax, x='density', y='Sao Paulo-bcc-relaxed',style='g-.',xlim=thisXlim)
dfrmf_bcc_relax.plot     (ax=ax, x='density', y='RMF-bcc-relaxed'      ,style='r-' ,xlim=thisXlim)
ax.set_xlabel("Density (g/$\\rm cm^3$)")
ax.set_ylabel("Rxn Rate (count/$\\rm cm^3$/sec)")
ax.set_title("bcc relaxed - Rxn Rate vs. Density")
plt.savefig(imagesDir + '/' + 'Schramm_bcc_relaxed_Rates-with-title.eps')

# %%
thisXlim = [0.9e9,1.0e10]
ax = dfm3y_bcc_relax.plot(       x='density', y='M3Y-bcc-relaxed'      ,style='k--',xlim=thisXlim)
dfsaopaulo_bcc_relax.plot(ax=ax, x='density', y='Sao Paulo-bcc-relaxed',style='g-.',xlim=thisXlim)
dfrmf_bcc_relax.plot     (ax=ax, x='density', y='RMF-bcc-relaxed'      ,style='r-' ,xlim=thisXlim)
ax.set_xlabel("Density (g/$\\rm cm^3$)")
ax.set_ylabel("Rxn Rate (count/$\\rm cm^3$/sec)")
#ax.set_title("bcc relaxed - Rxn Rate vs. Density")
#plt.savefig(imagesDir + '/' + 'Schramm_bcc_relaxed_Rates.eps')

# %%
thisXlim = [0.8e11,1.0e11]
ax = dfm3y_fcc_static.plot(x='density', y='M3Y-fcc-static',xlim=thisXlim)
dfsaopaulo_fcc_static.plot(ax=ax, x='density', y='Sao Paulo-fcc-static',xlim=thisXlim)
dfrmf_fcc_static.plot(ax=ax, x='density', y='RMF-fcc-static',xlim=thisXlim)
ax.set_xlabel("Density (g/$\\rm cm^3$)")
ax.set_ylabel("Rxn Rate (count/$\\rm cm^3$/sec)")
ax.set_title("fcc static - Rxn Rate vs. Density")

# %%
thisXlim = [0.8e11,1.0e11]
ax = dfm3y_fcc_ws.plot(       x='density', y='M3Y-fcc-ws'      ,xlim=thisXlim)
dfsaopaulo_fcc_ws.plot(ax=ax, x='density', y='Sao Paulo-fcc-ws',xlim=thisXlim)
dfrmf_fcc_ws.plot     (ax=ax, x='density', y='RMF-fcc-ws'      ,xlim=thisXlim)
ax.set_xlabel("Density (g/$\\rm cm^3$)")
ax.set_ylabel("Rxn Rate (count/$\\rm cm^3$/sec)")
ax.set_title("fcc ws - Rxn Rate vs. Density")

# %%
thisXlim = [0.8e11,1.0e11]
ax = dfm3y_fcc_relax.plot(       x='density', y='M3Y-fcc-relaxed'      ,xlim=thisXlim)
dfsaopaulo_fcc_relax.plot(ax=ax, x='density', y='Sao Paulo-fcc-relaxed',xlim=thisXlim)
dfrmf_fcc_relax.plot     (ax=ax, x='density', y='RMF-fcc-relaxed'      ,xlim=thisXlim)
ax.set_xlabel("Density (g/$\\rm cm^3$)")
ax.set_ylabel("Rxn Rate (count/$\\rm cm^3$/sec)")
ax.set_title("fcc relaxed - Rxn Rate vs. Density")

# %%
thisXlim = [0.8e11,1.0e11]
ax = dfm3y_fcc_relax.plot(       x='density', y='M3Y-fcc-relaxed'      ,xlim=thisXlim)
dfsaopaulo_fcc_relax.plot(ax=ax, x='density', y='Sao Paulo-fcc-relaxed',xlim=thisXlim)
dfrmf_fcc_relax.plot     (ax=ax, x='density', y='RMF-fcc-relaxed'      ,xlim=thisXlim)
ax.set_xlabel("Density (g/$\\rm cm^3$)")
ax.set_ylabel("Rxn Rate (count/$\\rm cm^3$/sec)")
ax.set_title("fcc relaxed - Rxn Rate vs. Density")

# %%
thisXlim = [1.0e10,1.0e11]
thisYlim = [1.0e10,1.0e38]
ax = dfrmf_fcc_static.plot(       x='density', y='RMF-fcc-static',style='k--' ,xlim=thisXlim,logy=True,logx=True,ylim=thisYlim)
dfrmf_fcc_relax.plot      (ax=ax, x='density', y='RMF-fcc-relaxed',style='g-.',xlim=thisXlim,logy=True,logx=True,ylim=thisYlim)
dfrmf_fcc_ws.plot         (ax=ax, x='density', y='RMF-fcc-ws',style='r-',xlim=thisXlim,logy=True,logx=True,ylim=thisYlim)
ax.set_xlabel("Log Density (g/$\\rm cm^3$)")
ax.set_ylabel("Log Rxn Rate (count/$\\rm cm^3$/sec)")
#ax.set_title("fcc RMF - Rxn Rate vs. Density")
plt.savefig(imagesDir + '/' + 'RMFSKapproxcomparison.eps')

# %%
thisXlim = [5e9,1.0e11]
thisYlim = [1.0e10,1.0e38]
ax = dfrmf_fcc_static.plot(       x='density', y='RMF-fcc-static',style='k--' ,xlim=thisXlim,logy=True,logx=True,ylim=thisYlim)
dfrmf_fcc_relax.plot      (ax=ax, x='density', y='RMF-fcc-relaxed',style='g-.',xlim=thisXlim,logy=True,logx=True,ylim=thisYlim)
dfrmf_fcc_ws.plot         (ax=ax, x='density', y='RMF-fcc-ws',style='r-',xlim=thisXlim,logy=True,logx=True,ylim=thisYlim)
ax.set_xlabel("Log Density (g/$\\rm cm^3$)")
ax.set_ylabel("Log Rxn Rate (count/$\\rm cm^3$/sec)")
ax.set_title("fcc RMF - Rxn Rate vs. Density")
plt.savefig(imagesDir + '/' + 'RMFSKapproxcomparison-with-title.eps')

# %%
ax = dfm3y_bcc_static.plot(       x='density', y='M3Y-bcc-static' ,xlim=thisXlim,logy=False,logx=False)
dfm3y_bcc_relax.plot      (ax=ax, x='density', y='M3Y-bcc-relaxed',xlim=thisXlim,logy=False,logx=False)
dfm3y_bcc_ws.plot         (ax=ax, x='density', y='M3Y-bcc-ws',xlim=thisXlim,logy=False,logx=False)
ax.set_xlabel("Density (g/$\\rm cm^3$)")
ax.set_ylabel("Rxn Rate (count/$\\rm cm^3$/sec)")
#ax.set_title("bcc M3Y - Rxn Rate vs. Density")
plt.savefig(imagesDir + '/' + 'M3YSKapproxcomparison.eps')

# %%
thisXlim = [5e9,1.0e11]
thisYlim = [1.0e10,1.0e38]
ax = dfm3y_bcc_static.plot(       x='density', y='M3Y-bcc-static' ,xlim=thisXlim,logy=True,logx=True,ylim=thisYlim)
dfm3y_bcc_relax.plot      (ax=ax, x='density', y='M3Y-bcc-relaxed',xlim=thisXlim,logy=True,logx=True,ylim=thisYlim)
ax.set_xlabel("Log Density (g/$\\rm cm^3$)")
ax.set_ylabel("Log Rxn Rate (count/$\\rm cm^3$/sec)")
ax.set_title("bcc M3Y - Rxn Rate vs. Density")
plt.savefig(imagesDir + '/' + 'M3YSKapproxcomparison-with-title.eps')

# %%
thisXlim = [1.0e10,1.0e11]
thisYlim = [1.0e10,1.0e38]
ax = dfsaopaulo_fcc_static.plot(       x='density', y='Sao Paulo-fcc-static' ,xlim=thisXlim,logy=True,logx=True,ylim=thisYlim)
dfsaopaulo_fcc_relax.plot      (ax=ax, x='density', y='Sao Paulo-fcc-relaxed',xlim=thisXlim,logy=True,logx=True,ylim=thisYlim)
ax.set_xlabel("Log Density (g/$\\rm cm^3$)")
ax.set_ylabel("Log Rxn Rate (count/$\\rm cm^3$/sec)")
ax.set_title("fcc Sao Paulo - Rxn Rate vs. Density")

# %%
thisXlim = [0.9e11,1.0e11]
thisYlim = [0.5e35,4.0e35]
ax = dfrmf_fcc_relax.plot(       x='density', y='RMF-fcc-relaxed' ,xlim=thisXlim,ylim=thisYlim)
dfrmf_bcc_relax.plot      (ax=ax, x='density', y='RMF-bcc-relaxed',xlim=thisXlim,ylim=thisYlim)
ax.set_xlabel("Density (g/$\\rm cm^3$)")
ax.set_ylabel("Rxn Rate (count/$\\rm cm^3$/sec)")
ax.set_title("RMF bcc and fcc relaxed - Rxn Rate vs. Density")
plt.savefig(imagesDir + '/' + 'fcc-bcc-compare-relaxed-with-title.eps')

# %%
Xlim = [0.9e11,1.0e11]
thisYlim = [0.0,0.5e34]
ax = dfrmf_fcc_static.plot(       x='density', y='RMF-fcc-static' ,xlim=thisXlim,ylim=thisYlim)
dfrmf_bcc_static.plot      (ax=ax, x='density', y='RMF-bcc-static',xlim=thisXlim,ylim=thisYlim)
ax.set_xlabel("Density (g/$\\rm cm^3$)")
ax.set_ylabel("Rxn Rate (count/$\\rm cm^3$/sec)")
ax.set_title("RMF bcc and fcc static - Rxn Rate vs. Density")
plt.savefig(imagesDir + '/' + 'fcc-bcc-compare-static-with-title.eps')

# %%
dfSFactor = pd.read_csv("../researchdata/graphSFactor.csv",index_col=False,skipinitialspace=True)

# %%
#ax = dfSFactor.plot(       x='Density', y='Sao Paulo')
#dfSFactor.plot     (ax=ax, x='Density', y='M3Y')
#dfSFactor.plot     (ax=ax, x='Density', y='RMF')
#ax.set_xlabel("Density (g/cm^3)")
#ax.set_ylabel("S Factor (MeV*barns)")
#ax.set_title("S Factor vs. Density")

#ax = dfSFactor.plot(kind='line',x='Density',y=['M3Y','Sao Paulo','RMF'],style=['k--','g-.','r-'],title="S Factor vs Density")
ax = dfSFactor.plot(kind='line',x='Density',y=['M3Y','Sao Paulo','RMF'],style=['k--','g-.','r-'])
ax.set_xlabel("Density (g/$\\rm cm^3$)")
ax.set_ylabel("S Factor (MeV-barns)")
#ax.set_title("S Factor vs. Density")
plt.savefig(imagesDir + '/' + 'SFactor.eps')

# %%
dftempadjustrho9 = pd.read_csv("../researchdata/temp_adjust_rho9.csv",index_col=False,skipinitialspace=True)

# %%
ax = dftempadjustrho9.plot(kind='line',x='temp',y=['adjust'],style=['k--'])
ax.set_xlabel("Temperature (K)")
ax.set_ylabel("Pycno Rxn Rate Adjustment")
#ax.set_title("Rate Adjust vs. Temp, rho=10^9")
plt.savefig(imagesDir + '/' + 'RateTempAdjust9.eps')

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')

X = np.loadtxt(open(rateDir + "/rho.csv", "rb"), delimiter=",")
Y = np.loadtxt(open(rateDir + "/temp.csv", "rb"), delimiter=",")
X, Y = np.meshgrid(X, Y)
Z = np.loadtxt(open(rateDir + "/tempadjuststatic.csv", "rb"), delimiter=",")
Z = np.transpose(Z)
Z = np.log10(Z)
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,linewidth=0, antialiased=False)
#ax.set_title('Log Temp Adjustment - Static')
ax.set_xlabel("Density gm/$cm^3$")
ax.set_ylabel("Temp. K")
plt.savefig(imagesDir + '/' + 'tempAdjustSurfStatic.eps')

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')

X = np.loadtxt(open(rateDir + "/rho.csv", "rb"), delimiter=",")
Y = np.loadtxt(open(rateDir + "/temp.csv", "rb"), delimiter=",")
X, Y = np.meshgrid(X, Y)
Z = np.loadtxt(open(rateDir + "/tempadjustrelaxed.csv", "rb"), delimiter=",")
Z = np.transpose(Z)
Z = np.log10(Z)
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,linewidth=0, antialiased=False)
#ax.set_title('Log Temp Adjustment - Relaxed')
ax.set_xlabel("Density gm/$cm^3$")
ax.set_ylabel("Temp. K")
plt.savefig(imagesDir + '/' + 'tempAdjustSurfRelaxed.eps')

# %%
print(X.shape)
print(Y.shape)
print(Z.shape)
